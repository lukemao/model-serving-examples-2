# %% [markdown]
# # Dataproc Machine Learning Demo
#
# In this notebook will demonstrate building a machine learning model using PySpark on Dataproc.
# Will build a model to predict taxi fares based on a public dataset covering NYC taxi records.

# %% [markdown]
# ## Import libraries and initialise spark

# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.linalg import DenseVector
from pyspark.sql.functions import isnan, when, count, col
import datetime as dt

# Initialise spark session
spark = SparkSession.builder.master('yarn').appName('spark-test').getOrCreate()

# Define temporary bucket for BQ connector
bucket = "pyspark_temp_20201006_eu"
spark.conf.set('temporaryGcsBucket', bucket)

# %% [markdown]
# ## Load data

# %%
# Load data from BigQuery.
df = spark.read.format('bigquery').option('table', 'sap-ds-demo:big_data_demo_ew2.ny_taxi_1k').load()
df.createOrReplaceTempView('taxi')

# %% [markdown]
# ## Explore data

# %%
df.limit(10).toPandas()
# Out:
#   vendor_id  journey_length  year  month  dayofweek  pu_hour  do_hour  \
# 0       CMT               3  2009      1          7        0        0
# 1       CMT               4  2009      1          6        0        0
# 2       CMT               2  2009      1          1        0        0
# 3       CMT               4  2009      1          6        0        0
# 4       CMT               3  2009      1          5        0        0
# 5       CMT               4  2009      1          4        0        0
# 6       CMT               4  2009      1          6        0        0
# 7       CMT               3  2009      1          6        0        0
# 8       CMT               3  2009      1          4        0        0
# 9       CMT               6  2009      1          3        0        0
#
#    passenger_count  trip_distance  pickup_longitude  rate_code  \
# 0                1            0.7        -73.998067  40.682297
# 1                1            0.7        -73.994757  40.728271
# 2                1            1.0        -73.952712  40.776503
# 3                1            0.7        -73.983303  40.761363
# 4                1            1.0        -73.968815  40.760197
# 5                2            0.8        -73.925570  40.762173
# 6                2            0.7        -73.990919  40.739789
# 7                1            1.0        -73.988933  40.764411
# 8                1            0.5        -73.985929  40.743614
# 9                1            1.7          0.000000   0.000000
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                            -73.992187         40.690419         Cash
# 1                            -73.987781         40.725424         Cash
# 2                            -73.962566         40.763019         Cash
# 3                            -73.971450         40.756312         Cash
# 4                            -73.958751         40.772449         Cash
# 5                            -73.938154         40.764812         Cash
# 6                            -73.987641         40.738260         Cash
# 7                            -73.982519         40.775709         Cash
# 8                            -73.988725         40.740323       Credit
# 9                              0.000000          0.000000         Cash
#
#    total_amount   pu_m_center   do_m_center      pu_m_jfk      do_m_jfk
# 0          5.00  7.543506e+03  6.558198e+03  7.543506e+03  6.558198e+03
# 1          5.00  5.021685e+03  4.464615e+03  5.021685e+03  4.464615e+03
# 2          5.00  5.311012e+03  4.276116e+03  5.311012e+03  4.276116e+03
# 3          5.00  5.299641e+03  4.180020e+03  5.299641e+03  4.180020e+03
# 4          5.00  4.338540e+03  5.056222e+03  4.338540e+03  5.056222e+03
# 5          5.00  3.602989e+03  3.810998e+03  3.602989e+03  3.810998e+03
# 6          5.00  4.800886e+03  4.496195e+03  4.800886e+03  4.496195e+03
# 7          5.00  5.880781e+03  6.403661e+03  5.880781e+03  6.403661e+03
# 8          5.75  4.508732e+03  4.633881e+03  4.508732e+03  4.633881e+03
# 9          7.00  8.661586e+06  8.661586e+06  8.661586e+06  8.661586e+06

# %%
print("Data length: {}".format(df.count()))
# Out:
# Data length: 1000

# %%
df.describe().toPandas()
# Out:
#   summary vendor_id     journey_length    year               month  \
# 0   count      1000               1000    1000                1000
# 1    mean      None             10.374  2009.0               6.386
# 2  stddev      None  7.298314147074608     0.0  3.4171158424438404
# 3     min       CMT                  0    2009                   1
# 4     max       CMT                 54    2009                  12
#
#             dayofweek pu_hour              do_hour     passenger_count  \
# 0                1000    1000                 1000                1000
# 1               4.248     0.0                0.148               1.409
# 2  2.2292297919832014     0.0  0.35527766918597936  0.7511879147612022
# 3                   1       0                    0                   1
# 4                   7       0                    1                   4
#
#         trip_distance  ...           rate_code    store_and_fwd_flag  \
# 0                1000  ...                1000                  1000
# 1  2.8490999999999946  ...   39.97032397499996  0.012687427912341407
# 2   2.800993529938039  ...  5.5654661649360815   0.11198625726559455
# 3                 0.0  ...                 0.0
# 4                20.5  ...           40.849635                     1
#
#     dropoff_longitude   dropoff_latitude payment_type        total_amount  \
# 0                1000               1000         1000                1000
# 1  -72.56991482899986  39.97190185800007         None  10.697440000000057
# 2  10.104574412163986  5.565733010226149         None  7.7881508035822815
# 3          -74.038249                0.0         Cash                 2.5
# 4                 0.0          40.955138    No Charge               71.94
#
#           pu_m_center         do_m_center            pu_m_jfk  \
# 0                1000                1000                1000
# 1  169850.98340087276  170012.31159386612  169850.98340087276
# 2   1182377.957431879  1182356.3327869084   1182377.957431879
# 3   1666.118136647689   588.0298057704706   1666.118136647689
# 4   8661585.636265686   8661585.636265686   8661585.636265686
#
#              do_m_jfk
# 0                1000
# 1  170012.31159386612
# 2  1182356.3327869084
# 3   588.0298057704706
# 4   8661585.636265686
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Prepare model data

# %%
model_data = df.select("total_amount", "journey_length", "year", "month", 
                         "dayofweek", "pu_hour", "do_hour", 
                         "passenger_count", "trip_distance", 
                         "pu_m_center", 
                         "do_m_center", "pu_m_jfk", "do_m_jfk")
model_data.toPandas()
# Out:
#      total_amount  journey_length  year  month  dayofweek  pu_hour  do_hour  \
# 0             5.0               3  2009      1          7        0        0
# 1             5.0               4  2009      1          6        0        0
# 2             5.0               2  2009      1          1        0        0
# 3             5.0               4  2009      1          6        0        0
# 4             5.0               3  2009      1          5        0        0
# ..            ...             ...   ...    ...        ...      ...      ...
# 995           8.7               6  2009     12          1        0        0
# 996          10.7              10  2009     12          3        0        1
# 997          10.7               9  2009     12          6        0        0
# 998          12.7              12  2009     12          6        0        0
# 999          13.7              15  2009     12          7        0        0
#
#      passenger_count  trip_distance  pu_m_center  do_m_center     pu_m_jfk  \
# 0                  1            0.7  7543.506091  6558.197960  7543.506091
# 1                  1            0.7  5021.685125  4464.615259  5021.685125
# 2                  1            1.0  5311.012485  4276.116166  5311.012485
# 3                  1            0.7  5299.640950  4180.020199  5299.640950
# 4                  1            1.0  4338.539500  5056.222290  4338.539500
# ..               ...            ...          ...          ...          ...
# 995                3            2.5  5981.473283  4873.163178  5981.473283
# 996                1            2.7  7135.936496  5736.789152  7135.936496
# 997                1            3.5  4243.779268  4854.155165  4243.779268
# 998                2            4.1  4555.891339  4555.891339  4555.891339
# 999                1            3.6  5387.436810  5487.547331  5387.436810
#
#         do_m_jfk
# 0    6558.197960
# 1    4464.615259
# 2    4276.116166
# 3    4180.020199
# 4    5056.222290
# ..           ...
# 995  4873.163178
# 996  5736.789152
# 997  4854.155165
# 998  4555.891339
# 999  5487.547331
#
# [1000 rows x 13 columns]

# %%
model_data_map = model_data.rdd.map(lambda x: (x[0], DenseVector(x[1:])))    
train_test = spark.createDataFrame(model_data_map, ["label", "features"])
train_test.toPandas()
# Out:
#      label                                           features
# 0      5.0  [3.0, 2009.0, 1.0, 7.0, 0.0, 0.0, 1.0, 0.7, 75...
# 1      5.0  [4.0, 2009.0, 1.0, 6.0, 0.0, 0.0, 1.0, 0.7, 50...
# 2      5.0  [2.0, 2009.0, 1.0, 1.0, 0.0, 0.0, 1.0, 1.0, 53...
# 3      5.0  [4.0, 2009.0, 1.0, 6.0, 0.0, 0.0, 1.0, 0.7, 52...
# 4      5.0  [3.0, 2009.0, 1.0, 5.0, 0.0, 0.0, 1.0, 1.0, 43...
# ..     ...                                                ...
# 995    8.7  [6.0, 2009.0, 12.0, 1.0, 0.0, 0.0, 3.0, 2.5, 5...
# 996   10.7  [10.0, 2009.0, 12.0, 3.0, 0.0, 1.0, 1.0, 2.7, ...
# 997   10.7  [9.0, 2009.0, 12.0, 6.0, 0.0, 0.0, 1.0, 3.5, 4...
# 998   12.7  [12.0, 2009.0, 12.0, 6.0, 0.0, 0.0, 2.0, 4.1, ...
# 999   13.7  [15.0, 2009.0, 12.0, 7.0, 0.0, 0.0, 1.0, 3.6, ...
#
# [1000 rows x 2 columns]

# %%
train, test = train_test.randomSplit([.8,.2],seed=1234)

# %% [markdown]
# ## Fit model

# %%
rf = RandomForestRegressor(featuresCol="features")
model = rf.fit(train)

# %% [markdown]
# ## Make predictions for test data

# %%
predictions = model.transform(test)

# %% [markdown]
# ## Evaluate test predictions

# %%
evaluator = RegressionEvaluator(
    labelCol="label", predictionCol="prediction", metricName="rmse")
rmse = evaluator.evaluate(predictions)
    
evaluator = RegressionEvaluator(
    labelCol="label", predictionCol="prediction", metricName="r2")
r2 = evaluator.evaluate(predictions)
    
print("RMSE: {:.2f}, R2 {:.2f}".format(rmse, r2))
# Out:
# RMSE: 3.69, R2 0.73

# %% [markdown]
# ## Load the data from GCS

# %%
taxi_1m = spark.read.load('gs://pyspark_temp_20201006_eu/ny_taxi_1m',
                    format='com.databricks.spark.csv', 
                    header='true', 
                    inferSchema='true').cache()

# %%
taxi_1m.toPandas()
# Out:
#        vendor_id  journey_length  year  month  dayofweek  pu_hour  do_hour  \
# 0              1              24  2015      3          2        0        0
# 1              1               5  2015      2          5        0        0
# 2              1              10  2016      2          7        0        0
# 3              1               7  2015      6          4        0        0
# 4              1              34  2015      8          1        0        0
# ...          ...             ...   ...    ...        ...      ...      ...
# 999995       CMT            1239  2009      7          6       23       20
# 999996       CMT               0  2009      5          5       23       23
# 999997       CMT               7  2009      3          7       23       23
# 999998       CMT              22  2009      2          6       23        0
# 999999       CMT              11  2009     12          5       23       23
#
#         passenger_count  trip_distance  pickup_longitude  rate_code  \
# 0                     1           17.3        -73.789612  40.646900
# 1                     2            1.1        -73.975731  40.744705
# 2                     1            3.6          0.000000   0.000000
# 3                     1            4.1        -73.974754  40.742111
# 4                     1           13.3        -74.004074  40.713142
# ...                 ...            ...               ...        ...
# 999995                1           15.3        -73.972213  40.786376
# 999996                1            0.0        -74.006290  40.739652
# 999997                1            2.2        -73.994046  40.751259
# 999998                4            7.8        -74.003080  40.749102
# 999999                1            1.7        -73.957882  40.773792
#
#        store_and_fwd_flag  dropoff_longitude  dropoff_latitude payment_type  \
# 0                       N         -73.985168         40.751045            1
# 1                       N         -73.968338         40.756252            1
# 2                       N         -74.009850         40.705559            1
# 3                       N         -74.006172         40.706516            1
# 4                       N         -73.876450         40.841442            1
# ...                   ...                ...               ...          ...
# 999995                  0         -73.934621         40.724848    No Charge
# 999996                  0         -74.006036         40.739841    No Charge
# 999997                  0         -73.981915         40.778080    No Charge
# 999998                  0         -73.931683         40.802867    No Charge
# 999999                  0         -73.981164         40.786877    No Charge
#
#         total_amount   pu_m_center   do_m_center      pu_m_jfk      do_m_jfk
# 0              72.66  1.540813e+04   4780.791020  1.540813e+04   4780.791020
# 1               7.30  3.754140e+03   3987.976902  3.754140e+03   3987.976902
# 2              17.15  8.661586e+06   6877.169890  8.661586e+06   6877.169890
# 3              17.15  3.566295e+03   6550.707277  3.566295e+03   6550.707277
# 4              46.80  6.117242e+03  13280.872906  6.117242e+03  13280.872906
# ...              ...           ...           ...           ...           ...
# 999995          2.50  6.938869e+03    642.839580  6.938869e+03    642.839580
# 999996          2.50  6.070091e+03   6052.507183  6.070091e+03   6052.507183
# 999997          8.20  5.460385e+03   6581.597964  5.460385e+03   6581.597964
# 999998         21.00  6.074007e+03   8040.213007  6.074007e+03   8040.213007
# 999999          9.10  5.166484e+03   7355.641394  5.166484e+03   7355.641394
#
# [1000000 rows x 20 columns]

# %%
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.eventLog.enabled', 'true'),
#  ('spark.dynamicAllocation.minExecutors', '1'),
#  ('spark.app.name', 'spark-test'),
#  ('spark.ui.proxyBase', '/proxy/application_1602494989817_0006'),
#  ('spark.driver.port', '44713'),
#  ('spark.driver.host', 'spark-jupyter-m.c.sap-ds-demo.internal'),
#  ('spark.yarn.am.memory', '640m'),
#  ('spark.yarn.historyServer.address', 'spark-jupyter-m:18080'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_HOSTS',
#   'spark-jupyter-m'),
#  ('spark.executorEnv.PYTHONPATH',
#   '{{PWD}}/pyspark.zip<CPS>{{PWD}}/py4j-0.10.7-src.zip'),
#  ('spark.executor.memory', '5586m'),
#  ('spark.executor.instances', '2'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.ui.filters',
#   'org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter'),
#  ('spark.app.id', 'application_1602494989817_0006'),
#  ('spark.driver.maxResultSize', '1920m'),
#  ('spark.shuffle.service.enabled', 'true'),
#  ('spark.scheduler.mode', 'FAIR'),
#  ('spark.hadoop.hive.execution.engine', 'mr'),
#  ('spark.yarn.jars', 'local:/usr/lib/spark/jars/*'),
#  ('spark.scheduler.minRegisteredResourcesRatio', '0.0'),
#  ('spark.executor.id', 'driver'),
#  ('spark.executor.cores', '2'),
#  ('spark.history.fs.logDirectory',
#   'hdfs://spark-jupyter-m/user/spark/eventlog'),
#  ('spark.dynamicAllocation.maxExecutors', '10000'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_URI_BASES',
#   'http://spark-jupyter-m:8088/proxy/application_1602494989817_0006'),
#  ('spark.master', 'yarn'),
#  ('spark.rpc.message.maxSize', '512'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.driver.appUIAddress',
#   'http://spark-jupyter-m.c.sap-ds-demo.internal:4042'),
#  ('spark.executorEnv.OPENBLAS_NUM_THREADS', '1'),
#  ('spark.driver.memory', '3840m'),
#  ('spark.yarn.isPython', 'true'),
#  ('spark.dynamicAllocation.enabled', 'true'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.eventLog.dir', 'hdfs://spark-jupyter-m/user/spark/eventlog'),
#  ('spark.sql.cbo.enabled', 'true')]
